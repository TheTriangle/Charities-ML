# %%
import pandas as pd

df = pd.read_excel('answers.xlsx')
print(df)
# Out:
#             ID       Время создания      Время изменения  \
# 0   1311191306  2023-02-12 16:46:53  2023-02-12 16:46:53
# 1   1311025212  2023-02-12 11:27:25  2023-02-12 11:27:25
# 2   1310845113  2023-02-11 23:16:43  2023-02-11 23:16:43
# 3   1309216774  2023-02-09 16:45:29  2023-02-09 16:45:29
# 4   1308822969  2023-02-09 08:13:56  2023-02-09 08:13:56
# 5   1308696138  2023-02-08 22:57:10  2023-02-08 22:57:10
# 6   1308515251  2023-02-08 18:02:50  2023-02-08 18:02:50
# 7   1308256077  2023-02-08 12:43:25  2023-02-08 12:43:25
# 8   1308232752  2023-02-08 12:14:02  2023-02-08 12:14:02
# 9   1308216282  2023-02-08 11:53:11  2023-02-08 11:53:11
# 10  1308196582  2023-02-08 11:28:42  2023-02-08 11:28:42
# 11  1308168244  2023-02-08 10:51:07  2023-02-08 10:51:07
# 12  1308161303  2023-02-08 10:41:45  2023-02-08 10:41:45
# 13  1308159865  2023-02-08 10:39:48  2023-02-08 10:39:48
# 14  1308158623  2023-02-08 10:38:07  2023-02-08 10:38:07
# 15  1308157842  2023-02-08 10:37:04  2023-02-08 10:37:04
# 16  1308155758  2023-02-08 10:34:18  2023-02-08 10:34:18
#
#    Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Размер организации  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                  Размер организации
# 6                                                 NaN
# 7                                  Размер организации
# 8                                                 NaN
# 9                                  Размер организации
# 10                                                NaN
# 11                                 Размер организации
# 12                                                NaN
# 13                                                NaN
# 14                                 Размер организации
# 15                                                NaN
# 16                                 Размер организации
#
#    Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Качественные отчеты  \
# 0                                 Качественные отчеты
# 1                                                 NaN
# 2                                 Качественные отчеты
# 3                                 Качественные отчеты
# 4                                                 NaN
# 5                                 Качественные отчеты
# 6                                 Качественные отчеты
# 7                                 Качественные отчеты
# 8                                                 NaN
# 9                                                 NaN
# 10                                Качественные отчеты
# 11                                Качественные отчеты
# 12                                                NaN
# 13                                                NaN
# 14                                Качественные отчеты
# 15                                Качественные отчеты
# 16                                                NaN
#
#    Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Хорошие отзывы  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                      Хорошие отзывы
# 3                                      Хорошие отзывы
# 4                                                 NaN
# 5                                      Хорошие отзывы
# 6                                      Хорошие отзывы
# 7                                      Хорошие отзывы
# 8                                                 NaN
# 9                                      Хорошие отзывы
# 10                                     Хорошие отзывы
# 11                                     Хорошие отзывы
# 12                                     Хорошие отзывы
# 13                                                NaN
# 14                                                NaN
# 15                                     Хорошие отзывы
# 16                                     Хорошие отзывы
#
#    Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Множество филиалов  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                  Множество филиалов
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
#    Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Географическое расположение организации  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10            Географическое расположение организации
# 11                                                NaN
# 12            Географическое расположение организации
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
#    Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Разнообразие кампаний по сбору средств  \
# 0              Разнообразие кампаний по сбору средств
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14             Разнообразие кампаний по сбору средств
# 15                                                NaN
# 16                                                NaN
#
#     Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Статус иноагента/его отсутствие  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
#     ... Расскажите, куда еще вы хотели бы пожертвовать.5  \
# 0   ...                                              NaN
# 1   ...                                              NaN
# 2   ...                                              NaN
# 3   ...                                              NaN
# 4   ...                                              NaN
# 5   ...                                              NaN
# 6   ...                                              NaN
# 7   ...                                              NaN
# 8   ...                                              NaN
# 9   ...                                              NaN
# 10  ...                                              NaN
# 11  ...                                              NaN
# 12  ...                                              NaN
# 13  ...                                              NaN
# 14  ...                                              NaN
# 15  ...                                              NaN
# 16  ...                                              NaN
#
#    Расскажите, сколько (необязательно).16  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
#
#    Расскажите, куда еще вы хотели бы пожертвовать.6  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
#
#    Расскажите, сколько (необязательно).17  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
#
#     Расскажите, куда еще вы хотели бы пожертвовать.7  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
#
#    Расскажите, сколько (необязательно).18  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
#
#    Расскажите, куда еще вы хотели бы пожертвовать.8  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
#
#    Расскажите, сколько (необязательно).19  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
#
#    ОГО! У вас много планов! Перечислите, пожалуйста, куда еще вы хотели бы пожертвовать, здесь  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
#    Спасибо еще раз, что согласились ответить на наши вопросы! Мы проконсультировались с экспертами из крупнейших Российских фондов, чтобы понять, как облегчить поиск новых интересных некоммерческих организаций. Если у вас есть потребность в удобном приложении, которое помогло бы в этом процессе, вы можете оставить feature request (предложения для функционала) ниже. Если вы даже настолько заинтересованы, что хотели бы, чтобы мы отправили вам весточку, когда наше приложение выйдет в мир, вы можете также оставить здесь вашу почту.
# 0                           yana.perminova.02@mail.ru
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                               alexcor2810@gmail.com
# 6                                                 NaN
# 7   Успехов с разработкой!!!\r\nБуду рад воспользо...
# 8                                                 NaN
# 9                              reznickdarya@gmail.com
# 10                           ovcharovaroni413@mail.ru
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
# [17 rows x 63 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Время создания', 'Время изменения',
#        'Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Размер организации',
#        'Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Качественные отчеты',
#        'Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Хорошие отзывы',
#        'Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Множество филиалов',
#        'Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Географическое расположение организации',
#        'Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Разнообразие кампаний по сбору средств',
#        'Расскажите, что вам важно в организации, когда вы решаете, жертвовать ей, или нет? / Статус иноагента/его отсутствие',
#        'Расскажите, на основе чего еще вы делаете свой выбор?',
#        'Расскажите, на чем специализируются организации, которые вас интересуют больше всего? / Работа с детьми',
#        'Расскажите, на чем специализируются организации, которые вас интересуют больше всего? / Борьба с бедностью',
#        'Расскажите, на чем специализируются организации, которые вас интересуют больше всего? / Наука и исследования',
#        'Расскажите, на чем специализируются организации, которые вас интересуют больше всего? / Искусство',
#        'Расскажите, на чем специализируются организации, которые вас интересуют больше всего? / Здравоохранение',
#        'Расскажите, на чем специализируются организации, которые вас интересуют больше всего? / Образование',
#        'Расскажите, на чем специализируются организации, которые вас интересуют больше всего? / Работа с животными',
#        'Расскажите, на чем специализируются организации, которые вас интересуют больше всего? / Обеспечение прав и свобод человека',
#        'Если вы предпочитаете организации с другой специализацией, пожалуйста, укажите',
#        'Расскажите, куда вы уже жертвовали',
#        'Расскажите, сколько (необязательно)',
#        'Расскажите, куда еще вы уже жертвовали',
#        'Расскажите, сколько (необязательно).1',
#        'Расскажите, куда еще вы уже жертвовали.1',
#        'Расскажите, сколько (необязательно).2',
#        'Расскажите, куда еще вы уже жертвовали.2',
#        'Расскажите, сколько (необязательно).3',
#        'Расскажите, куда еще вы уже жертвовали.3',
#        'Расскажите, сколько (необязательно).4',
#        'Расскажите, куда еще вы уже жертвовали.4',
#        'Расскажите, сколько (необязательно).5',
#        'Расскажите, куда еще вы уже жертвовали.5',
#        'Расскажите, сколько (необязательно).6',
#        'Расскажите, куда еще вы уже жертвовали.6',
#        'Расскажите, сколько (необязательно).7',
#        'Расскажите, куда еще вы уже жертвовали.7',
#        'Расскажите, сколько (необязательно).8',
#        'Расскажите, куда еще вы уже жертвовали.8',
#        'Расскажите, сколько (необязательно).9',
#        'ОГО! Вы по-настоящему щедрый человек! Перечислите, пожалуйста, куда еще вы жертвовали, здесь',
#        'Расскажите, куда вы хотели бы пожертвовать',
#        'Расскажите, сколько (необязательно).10',
#        'Расскажите, куда еще вы хотели бы пожертвовать',
#        'Расскажите, сколько (необязательно).11',
#        'Расскажите, куда еще вы хотели бы пожертвовать.1',
#        'Расскажите, сколько (необязательно).12',
#        'Расскажите, куда еще вы хотели бы пожертвовать.2',
#        'Расскажите, сколько (необязательно).13',
#        'Расскажите, куда еще вы хотели бы пожертвовать.3',
#        'Расскажите, сколько (необязательно).14',
#        'Расскажите, куда еще вы хотели бы пожертвовать.4',
#        'Расскажите, сколько (необязательно).15',
#        'Расскажите, куда еще вы хотели бы пожертвовать.5',
#        'Расскажите, сколько (необязательно).16',
#        'Расскажите, куда еще вы хотели бы пожертвовать.6',
#        'Расскажите, сколько (необязательно).17',
#        'Расскажите, куда еще вы хотели бы пожертвовать.7',
#        'Расскажите, сколько (необязательно).18',
#        'Расскажите, куда еще вы хотели бы пожертвовать.8',
#        'Расскажите, сколько (необязательно).19',
#        'ОГО! У вас много планов! Перечислите, пожалуйста, куда еще вы хотели бы пожертвовать, здесь',
#        'Спасибо еще раз, что согласились ответить на наши вопросы! Мы проконсультировались с экспертами из крупнейших Российских фондов, чтобы понять, как облегчить поиск новых интересных некоммерческих организаций. Если у вас есть потребность в удобном приложении, которое помогло бы в этом процессе, вы можете оставить feature request (предложения для функционала) ниже. Если вы даже настолько заинтересованы, что хотели бы, чтобы мы отправили вам весточку, когда наше приложение выйдет в мир, вы можете также оставить здесь вашу почту.'],
#       dtype='object')

# %%
# first step: transform table into something readable

#output format: list of dicts

#
# importance order: [Размер, Отчеты, Отзывы, Филиалы, Расположение, Кампании]
# tags order: [Работа с детьми, Борьба с бедностью, Наука и исследования, 
# Искусство, Здравоохранение, Образование, Работа с животными, Обеспечение прав и свобод человека]
#
# { 'organisations' : [['Благотворительная организация «Ночлежка»', 100], ['ОВД-Инфо', 200], [...] ...], 
#'importance': [1, 1, 0, 0, 1, 0]}
#'additional_importance' : 'Наличие на сайте информации о проведенных кампаниях: на что потрачены деньги, что получилось'
#'tags': [1, 0, 0, 1, 0, 1, 1, 1]
#'additional_tags': 'Экология' }

# %%
import math
import time
import re
import random
import string
print(df.shape)
print(type(df['Расскажите, куда еще вы уже жертвовали'][2]))
# Out:
# (17, 63)
# <class 'float'>

# %%
from google.cloud import bigquery
client = bigquery.Client(project='donapp-d2378')
dataset_id = 'firebase_recommendations_dataset'
# For this sample, the table must already exist and have a defined schematable_id = ‘test_table_creation’
table_ref = client.dataset(dataset_id).table('donations_table')
table = client.get_table(table_ref)
# Creating a list of tuples with the values that shall be inserted into the table

# %%
import firebase_admin
from firebase_admin import firestore
from firebase_admin import credentials

# Use the application default credentials.
cred = credentials.Certificate('donapp-d2378-firebase-adminsdk-zxd1d-2147e3a97f.json') 
app = firebase_admin.initialize_app(cred)

db = firestore.client()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 7
#       5 # Use the application default credentials.
#       6 cred = credentials.Certificate('donapp-d2378-firebase-adminsdk-zxd1d-2147e3a97f.json')
# ----> 7 app = firebase_admin.initialize_app(cred)
#       9 db = firestore.client()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\firebase_admin\__init__.py:71, in initialize_app(credential, options, name)
#      68         return app
#      70 if name == _DEFAULT_APP_NAME:
# ---> 71     raise ValueError((
#      72         'The default Firebase app already exists. This means you called '
#      73         'initialize_app() more than once without providing an app name as '
#      74         'the second argument. In most cases you only need to call '
#      75         'initialize_app() once. But if you do want to initialize multiple '
#      76         'apps, pass a second argument to initialize_app() to give each app '
#      77         'a unique name.'))
#      79 raise ValueError((
#      80     'Firebase app named "{0}" already exists. This means you called '
#      81     'initialize_app() more than once with the same app name as the '
#      82     'second argument. Make sure you provide a unique name every time '
#      83     'you call initialize_app().').format(name))
#
# ValueError: The default Firebase app already exists. This means you called initialize_app() more than once without providing an app name as the second argument. In most cases you only need to call initialize_app() once. But if you do want to initialize multiple apps, pass a second argument to initialize_app() to give each app a unique name.

# %%
rows_to_insert = []
def insert_into_table(userID, primaryid, amount, timestamp):
    rows_to_insert.append({
    u'userID': userID,
    u'charityID': primaryid,
    u'amount': amount,
    u'timestamp': timestamp,
    })

confusingcharities = []
confusingamounts = []


def add_entry(charityname, amount, userID, timestamp):
    print(userID, '|', charityname, '|', amount, '|', timestamp)
    if isinstance(charityname, list):
        for i in range(len(charityname)):
            if isinstance(amount, list):
                if (i < len(amount)):   
                    add_entry(charityname[i], amount, userID, timestamp)
                else:
                    add_entry(charityname[i], 'nan', userID, timestamp)
            else:
                add_entry(charityname[i], 'nan', userID, timestamp)
        return
    
    charities = db.collection(u'charityaliases')
    lookupref = charities.document(charityname)
    doc = lookupref.get()
    primaryname = ''
    primaryid = ''
    if not doc.exists:
        print('what is: ' + charityname)
        primaryname = input()
        if primaryname == '?':
            confusingcharities.append(charityname)
            confusingamounts.append(confusingamounts)
            return
        primarydoc = charities.document(primaryname).get()
        if not primarydoc.exists:
            random.seed(timestamp)
            cid = ''.join(random.choices(string.ascii_uppercase + string.digits + string.ascii_lowercase, k=28))
            charities.document(primaryname).set({'primary': primaryname, 'id': cid})
            primaryid = cid
        else:
            primaryid = primarydoc.to_dict()['id']
        charities.document(charityname).set({'primary': primaryname, 'id': primaryid})
    else:
        primaryname = doc.to_dict()['primary']
        primaryid = doc.to_dict()['id']
    
    iamount = 0
    if not amount == 'nan':
        try:
            iamount = int(amount)
            amount = str(iamount)
        except:
            print('how much is: ', amount)
            amount = input()
            if amount == '?':
                amount = 'nan'
    
    insert_into_table(userID, primaryid, amount, timestamp)

# %%
votes = []
already = ['Расскажите, куда вы уже жертвовали',
       'Расскажите, сколько (необязательно)',
       'Расскажите, куда еще вы уже жертвовали',
       'Расскажите, сколько (необязательно).1',
       'Расскажите, куда еще вы уже жертвовали.1',
       'Расскажите, сколько (необязательно).2',
       'Расскажите, куда еще вы уже жертвовали.2',
       'Расскажите, сколько (необязательно).3',
       'Расскажите, куда еще вы уже жертвовали.3',
       'Расскажите, сколько (необязательно).4',
       'Расскажите, куда еще вы уже жертвовали.4',
       'Расскажите, сколько (необязательно).5',
       'Расскажите, куда еще вы уже жертвовали.5',
       'Расскажите, сколько (необязательно).6',
       'Расскажите, куда еще вы уже жертвовали.6',
       'Расскажите, сколько (необязательно).7',
       'Расскажите, куда еще вы уже жертвовали.7',
       'Расскажите, сколько (необязательно).8',
       'Расскажите, куда еще вы уже жертвовали.8',
       'Расскажите, сколько (необязательно).9',
       'ОГО! Вы по-настоящему щедрый человек! Перечислите, пожалуйста, куда еще вы жертвовали, здесь']

planned = ['Расскажите, куда вы хотели бы пожертвовать',
       'Расскажите, сколько (необязательно).10',
       'Расскажите, куда еще вы хотели бы пожертвовать',
       'Расскажите, сколько (необязательно).11',
       'Расскажите, куда еще вы хотели бы пожертвовать.1',
       'Расскажите, сколько (необязательно).12',
       'Расскажите, куда еще вы хотели бы пожертвовать.2',
       'Расскажите, сколько (необязательно).13',
       'Расскажите, куда еще вы хотели бы пожертвовать.3',
       'Расскажите, сколько (необязательно).14',
       'Расскажите, куда еще вы хотели бы пожертвовать.4',
       'Расскажите, сколько (необязательно).15',
       'Расскажите, куда еще вы хотели бы пожертвовать.5',
       'Расскажите, сколько (необязательно).16',
       'Расскажите, куда еще вы хотели бы пожертвовать.6',
       'Расскажите, сколько (необязательно).17',
       'Расскажите, куда еще вы хотели бы пожертвовать.7',
       'Расскажите, сколько (необязательно).18',
       'Расскажите, куда еще вы хотели бы пожертвовать.8',
       'Расскажите, сколько (необязательно).19',
       'ОГО! У вас много планов! Перечислите, пожалуйста, куда еще вы хотели бы пожертвовать, здесь']

def send_charities(charitynames, amounts, userID, timestamp):
    for j in range(len(charitynames)):
        if j >= len(amounts):
            add_entry(charitynames[j], 'nan', userID, timestamp)
        else:   
            add_entry(charitynames[j], amounts[j], userID, timestamp)
        timestamp += 1
    return timestamp

def parse_columns(nametables):
    random.seed(0)
    timestamp = int(time.time())
    for i in range(df.shape[0]):
        newUserId = ''.join(random.choices(string.ascii_uppercase + string.digits + string.ascii_lowercase, k=28))
        newUserId
        j = 0

        if isinstance(df[nametables[j]][i], float):
            continue

        charitynames =  df[nametables[j]][i].split(',')
        if isinstance(df[nametables[j + 1]][i], float):
            amounts = []
        else:
            amounts = df[nametables[j + 1]][i].split(',')
        if not len(charitynames) == 1:
            timestamp = send_charities(charitynames, amounts, newUserId, timestamp)

        while j < 20:
            charityname = df[nametables[j]][i]
            if isinstance(charityname, float):
                break
            amount = df[nametables[j + 1]][i]
            add_entry(charitynames, amount, newUserId, timestamp)
            j += 2
            timestamp += 1

        if j == 20:
            charitynames = df[nametables[j]][i].split(',')
            timestamp = send_charities(charitynames, [], newUserID, timestamp)
            
parse_columns(already)
parse_columns(planned)


errors = client.insert_rows(table, rows_to_insert) 
print(errors)
# Out:
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b | Дари Еду | Дари Еду - подписка | 1678288330
# how much is:  Дари Еду - подписка
# ?
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b |  РусДог |  200 р в месяц. РусДог и небольшие приюты - разово в зависимости от кампании | 1678288331
# how much is:   200 р в месяц. РусДог и небольшие приюты - разово в зависимости от кампании
# 400
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b |  небольшие приюты для животных |  300-1000 рублей. WWF - покупка мерча | 1678288332
# what is:  небольшие приюты для животных
# ?
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b |  WWF |  2000 р | 1678288333
# how much is:   2000 р
# 2000
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b | ['Дари Еду', ' РусДог', ' небольшие приюты для животных', ' WWF'] | Дари Еду - подписка, 200 р в месяц. РусДог и небольшие приюты - разово в зависимости от кампании, 300-1000 рублей. WWF - покупка мерча, 2000 р | 1678288334
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b | Дари Еду | nan | 1678288334
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b |  РусДог | nan | 1678288334
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b |  небольшие приюты для животных | nan | 1678288334
# what is:  небольшие приюты для животных
# ?
# qk0Q5ZmS3au5RkcPuyotTjtg3G0b |  WWF | nan | 1678288334
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [57], line 87
#      84             charitynames = df[nametables[j]][i].split(',')
#      85             timestamp = send_charities(charitynames, [], newUserID, timestamp)
# ---> 87 parse_columns(already)
#      88 parse_columns(planned)
#      91 errors = client.insert_rows(table, rows_to_insert)
#
# Cell In [57], line 79, in parse_columns(nametables)
#      77     break
#      78 amount = df[nametables[j + 1]][i]
# ---> 79 add_entry(charitynames, amount, newUserId, timestamp)
#      80 j += 2
#      81 timestamp += 1
#
# Cell In [56], line 27, in add_entry(charityname, amount, userID, timestamp)
#      24             add_entry(charityname[i], 'nan', userID, timestamp)
#      26 charities = db.collection(u'charityaliases')
# ---> 27 lookupref = charities.document(charityname)
#      28 doc = lookupref.get()
#      29 primaryname = ''
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\firestore_v1\base_collection.py:136, in BaseCollectionReference.document(self, document_id)
#     132 # Append `self._path` and the passed document's ID as long as the first
#     133 # element in the path is not an empty string, which comes from setting the
#     134 # parent to "" for recursive queries.
#     135 child_path = self._path + (document_id,) if self._path[0] else (document_id,)
# --> 136 return self._client.document(*child_path)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\firestore_v1\client.py:209, in Client.document(self, *document_path)
#     177 def document(self, *document_path: str) -> DocumentReference:
#     178     """Get a reference to a document in a collection.
#     179
#     180     For a top-level document:
#    (...)
#     206         A reference to a document in a collection.
#     207     """
#     208     return DocumentReference(
# --> 209         *self._document_path_helper(*document_path), client=self
#     210     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\google\cloud\firestore_v1\base_client.py:320, in BaseClient._document_path_helper(self, *document_path)
#     318 path = _path_helper(document_path)
#     319 base_path = self._database_string + "/documents/"
# --> 320 joined_path = _helpers.DOCUMENT_PATH_DELIMITER.join(path)
#     321 if joined_path.startswith(base_path):
#     322     joined_path = joined_path[len(base_path) :]
#
# TypeError: sequence item 1: expected str instance, list found
